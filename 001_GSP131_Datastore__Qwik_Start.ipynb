# %% [markdown]
# [Datastore: Qwik Start](https://www.cloudskillsboost.google/focuses/941?catalog_rank=%7B%22rank%22%3A12%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&parent=catalog&search_id=23679200)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.03.55.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.04.30.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.18.50.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.06.03.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.20.14.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.09.53.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.21.44.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.10.57.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.12.25.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.25.02.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.13.53.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.28.37.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.29.16.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.29.45.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.32.33.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.32.54.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.33.40.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.34.08.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.34.48.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.35.16.png](data:image/png;base64,...)

# %%
SELECT * FROM Task

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.36.11.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/datastore/docs/reference/gql_reference

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.37.11.png](data:image/png;base64,...)

# %%
SELECT * FROM Task WHERE done=false

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.40.13.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.38.25.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.41.05.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.40.59.png](data:image/png;base64,...)![Zrzut ekranu 2023-05-7 o 07.41.05.png](data:image/png;base64,...)

# %%
SELECT * FROM Task WHERE done=true

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.42.36.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-05-7 o 07.43.21.png](data:image/png;base64,...)
